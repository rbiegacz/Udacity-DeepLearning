# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def convert_line_to_ids(line, vocab_to_int, end_sentence=False):
    line_vocab = line.split()
    if end_sentence:
        line_vocab.append('<EOS>')
    return [ vocab_to_int[word] for word in line_vocab ]

def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    # in fact, what is expected here is:
    # each line is represented as array item so build an array where each line is an alement of an array
    # then a given array item represents a sequence of words from a particual line
    # so source_id_text is two-dimensional array, similarly target_id_text
    source_text_lines = source_text.split('\n')
    source_id_text = [convert_line_to_ids(line, source_vocab_to_int) for line in source_text_lines]
    target_text_lines = target_text.split('\n')
    target_id_text = [convert_line_to_ids(line, target_vocab_to_int, True) for line in target_text_lines]
    #print(source_id_text)
    #print(target_id_text)
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_len = tf.placeholder(tf.int32, shape = [None], name='target_sequence_length')
    max_target_len = tf.reduce_max(target_len, name='max_target_len')
    source_len = tf.placeholder(tf.int32, shape = [None], name='source_sequence_length')
    return input, targets, learning_rate, keep_prob, target_len, max_target_len, source_len


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    # let's take all the rows but truncate the last lement [-1] notation is perfect for that
    # target_data is a Tensorflow Placeholder
    # print(target_data)
    target_data_truncated = target_data[:, :-1]
    # number of columns should be smaller by 1
    # print(target_data)

    
    # Let's use tf.fill to create one columned of size batch_size x 1 filled with 'GO' command
    # We will use tf.concat to add 'GO' command to each of the sequences
    result = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), target_data_truncated], 1)
    return result

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function

    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size);

    def cell():
        # let's create a lstm_cell - size of it is determined by rnn_size parameter
        lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        # let's implement dropout with proability of keeping a given output = keep_prob
        drop_cell = tf.contrib.rnn.DropoutWrapper(lstm_cell, output_keep_prob=keep_prob) 
        return drop_cell
    
    # let's implement RNN network consisting of <num_layers> of LSTM cells
    encoding_cell = tf.contrib.rnn.MultiRNNCell([cell() for _ in range(num_layers)], state_is_tuple=True)
    
    encoder_output, encoder_state = tf.nn.dynamic_rnn(encoding_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    return encoder_output, encoder_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    
    # Helper object needed by BasicDecoder
    # it reads a sequence of ints from encoding layer
    train_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, sequence_length=target_sequence_length, time_major=False)
    
    # let's build a Decoder based on Decoder RNN Cell and Helper (built earlier in this function)
    train_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, train_helper, encoder_state, output_layer)

    # dynamic_decode creates outputs for training
    train_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(train_decoder, output_time_major=False, impute_finished=True, maximum_iterations=max_summary_length)
    return train_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    
    # not sure if we need this... let's see
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')

    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, start_tokens, end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, inference_helper, encoder_state, output_layer)

    # Perform dynamic decoding using the decoder
    inference_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                        impute_finished=True,
                                                        maximum_iterations=max_target_sequence_length)
    
    return inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # 1.-5. refer to the hints given above decoding_layer function
    # 1. Decoder Embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
     
    # 2. Construct the decoder LSTM cell (just like you constructed the encoder cell above)
    def cell():
        return tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
     
    with tf.variable_scope("decode"): 
        dec_cell = tf.contrib.rnn.MultiRNNCell([cell() for _ in range(num_layers)])
    
    # 3. Create an output layer to map the outputs of the decoder to the elements of our vocabulary
    output_layer = Dense(target_vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    # Using tf.variable_scope to share variables between training and inference.
    # 4. getting training logits
    with tf.variable_scope("decode"):        
        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, output_layer, keep_prob)
    
    # 5. getting inference logits
    # Reuses the same parameters trained by the training process
    with tf.variable_scope("decode", reuse=True):
        #start_tokens = tf.tile(tf.constant([target_vocab_to_int['<GO>']], dtype=tf.int32), [batch_size], name='start_tokens')
        #end_tokens = tf.tile(tf.constant([target_vocab_to_int['<EOS>']], dtype=tf.int32), [batch_size], name='end_tokens')
        start_tokens = target_vocab_to_int['<GO>']
        end_tokens = target_vocab_to_int['<EOS>']
        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_tokens,
                         end_tokens, max_target_sequence_length,
                         target_vocab_size, output_layer, batch_size, keep_prob)        
    
    return training_decoder_output, inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # applying embedding to the input
    enc_output, enc_state = encoding_layer(input_data, rnn_size, num_layers, 
                                  keep_prob, source_sequence_length, source_vocab_size, enc_embedding_size)
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    # Applying embedding to the target data for the decoder.
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input, 
                                                                       enc_state,
                                                                       target_sequence_length,
                                                                       max_target_sentence_length,
                                                                       rnn_size,
                                                                       num_layers, 
                                                                       target_vocab_to_int,
                                                                       target_vocab_size,
                                                                       batch_size, keep_prob,
                                                                       dec_embedding_size) 
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 9
# epochs = 1
# Batch Size
#batch_size = 128
batch_size = 64
# RNN Size
rnn_size = 200
# Number of Layers
# num_layers = 10
num_layers = 5
# Embedding Size
encoding_embedding_size = 20
decoding_embedding_size = 20
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.95
display_step = 50

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   50/2154 - Train Accuracy: 0.3586, Validation Accuracy: 0.4382, Loss: 2.8722
# Epoch   0 Batch  100/2154 - Train Accuracy: 0.3981, Validation Accuracy: 0.4226, Loss: 2.4693
# Epoch   0 Batch  150/2154 - Train Accuracy: 0.4382, Validation Accuracy: 0.4695, Loss: 2.1053
# Epoch   0 Batch  200/2154 - Train Accuracy: 0.4266, Validation Accuracy: 0.4822, Loss: 1.9873
# Epoch   0 Batch  250/2154 - Train Accuracy: 0.4445, Validation Accuracy: 0.4773, Loss: 1.8815
# Epoch   0 Batch  300/2154 - Train Accuracy: 0.3898, Validation Accuracy: 0.4652, Loss: 1.9402
# Epoch   0 Batch  350/2154 - Train Accuracy: 0.4406, Validation Accuracy: 0.4645, Loss: 1.5455
# Epoch   0 Batch  400/2154 - Train Accuracy: 0.4797, Validation Accuracy: 0.4908, Loss: 1.4959
# Epoch   0 Batch  450/2154 - Train Accuracy: 0.4766, Validation Accuracy: 0.4986, Loss: 1.3739
# Epoch   0 Batch  500/2154 - Train Accuracy: 0.4630, Validation Accuracy: 0.4858, Loss: 1.3441
# Epoch   0 Batch  550/2154 - Train Accuracy: 0.4918, Validation Accuracy: 0.4851, Loss: 1.3210
# Epoch   0 Batch  600/2154 - Train Accuracy: 0.4638, Validation Accuracy: 0.4730, Loss: 1.1889
# Epoch   0 Batch  650/2154 - Train Accuracy: 0.4352, Validation Accuracy: 0.5043, Loss: 1.2843
# Epoch   0 Batch  700/2154 - Train Accuracy: 0.4581, Validation Accuracy: 0.4943, Loss: 1.0439
# Epoch   0 Batch  750/2154 - Train Accuracy: 0.4562, Validation Accuracy: 0.5291, Loss: 1.0629
# Epoch   0 Batch  800/2154 - Train Accuracy: 0.4285, Validation Accuracy: 0.4922, Loss: 1.0359
# Epoch   0 Batch  850/2154 - Train Accuracy: 0.4719, Validation Accuracy: 0.5007, Loss: 0.8596
# Epoch   0 Batch  900/2154 - Train Accuracy: 0.4951, Validation Accuracy: 0.4964, Loss: 0.9534
# Epoch   0 Batch  950/2154 - Train Accuracy: 0.5658, Validation Accuracy: 0.5455, Loss: 0.8772
# Epoch   0 Batch 1000/2154 - Train Accuracy: 0.5387, Validation Accuracy: 0.5646, Loss: 0.7496
# Epoch   0 Batch 1050/2154 - Train Accuracy: 0.4883, Validation Accuracy: 0.5540, Loss: 0.8149
# Epoch   0 Batch 1100/2154 - Train Accuracy: 0.5094, Validation Accuracy: 0.5518, Loss: 0.8109
# Epoch   0 Batch 1150/2154 - Train Accuracy: 0.5493, Validation Accuracy: 0.5298, Loss: 0.7458
# Epoch   0 Batch 1200/2154 - Train Accuracy: 0.5403, Validation Accuracy: 0.5625, Loss: 0.8551
# Epoch   0 Batch 1250/2154 - Train Accuracy: 0.5437, Validation Accuracy: 0.5391, Loss: 0.7337
# Epoch   0 Batch 1300/2154 - Train Accuracy: 0.5023, Validation Accuracy: 0.5653, Loss: 0.7426
# Epoch   0 Batch 1350/2154 - Train Accuracy: 0.5547, Validation Accuracy: 0.5746, Loss: 0.6941
# Epoch   0 Batch 1400/2154 - Train Accuracy: 0.4868, Validation Accuracy: 0.5341, Loss: 0.7060
# Epoch   0 Batch 1450/2154 - Train Accuracy: 0.5502, Validation Accuracy: 0.5561, Loss: 0.6586
# Epoch   0 Batch 1500/2154 - Train Accuracy: 0.5395, Validation Accuracy: 0.5540, Loss: 0.6820
# Epoch   0 Batch 1550/2154 - Train Accuracy: 0.6125, Validation Accuracy: 0.5675, Loss: 0.6483
# Epoch   0 Batch 1600/2154 - Train Accuracy: 0.6102, Validation Accuracy: 0.5348, Loss: 0.6309
# Epoch   0 Batch 1650/2154 - Train Accuracy: 0.5982, Validation Accuracy: 0.5966, Loss: 0.5521
# Epoch   0 Batch 1700/2154 - Train Accuracy: 0.6062, Validation Accuracy: 0.5845, Loss: 0.5465
# Epoch   0 Batch 1750/2154 - Train Accuracy: 0.5844, Validation Accuracy: 0.6165, Loss: 0.5604
# Epoch   0 Batch 1800/2154 - Train Accuracy: 0.6109, Validation Accuracy: 0.5973, Loss: 0.5844
# Epoch   0 Batch 1850/2154 - Train Accuracy: 0.5781, Validation Accuracy: 0.6122, Loss: 0.6166
# Epoch   0 Batch 1900/2154 - Train Accuracy: 0.6492, Validation Accuracy: 0.6065, Loss: 0.4927
# Epoch   0 Batch 1950/2154 - Train Accuracy: 0.6070, Validation Accuracy: 0.5930, Loss: 0.5237
# Epoch   0 Batch 2000/2154 - Train Accuracy: 0.6070, Validation Accuracy: 0.5980, Loss: 0.5104
# Epoch   0 Batch 2050/2154 - Train Accuracy: 0.6217, Validation Accuracy: 0.6129, Loss: 0.5671
# Epoch   0 Batch 2100/2154 - Train Accuracy: 0.6766, Validation Accuracy: 0.6357, Loss: 0.4811
# Epoch   0 Batch 2150/2154 - Train Accuracy: 0.6555, Validation Accuracy: 0.6342, Loss: 0.5147
# Epoch   1 Batch   50/2154 - Train Accuracy: 0.6382, Validation Accuracy: 0.6307, Loss: 0.5044
# Epoch   1 Batch  100/2154 - Train Accuracy: 0.5960, Validation Accuracy: 0.6186, Loss: 0.4883
# Epoch   1 Batch  150/2154 - Train Accuracy: 0.6540, Validation Accuracy: 0.6143, Loss: 0.4268
# Epoch   1 Batch  200/2154 - Train Accuracy: 0.6242, Validation Accuracy: 0.6172, Loss: 0.4327
# Epoch   1 Batch  250/2154 - Train Accuracy: 0.7008, Validation Accuracy: 0.6314, Loss: 0.4356
# Epoch   1 Batch  300/2154 - Train Accuracy: 0.6604, Validation Accuracy: 0.6250, Loss: 0.4517
# Epoch   1 Batch  350/2154 - Train Accuracy: 0.7102, Validation Accuracy: 0.6435, Loss: 0.4560
# Epoch   1 Batch  400/2154 - Train Accuracy: 0.6953, Validation Accuracy: 0.6548, Loss: 0.3871
# Epoch   1 Batch  450/2154 - Train Accuracy: 0.7367, Validation Accuracy: 0.6491, Loss: 0.3703
# Epoch   1 Batch  500/2154 - Train Accuracy: 0.7245, Validation Accuracy: 0.6598, Loss: 0.3690
# Epoch   1 Batch  550/2154 - Train Accuracy: 0.7195, Validation Accuracy: 0.6555, Loss: 0.3930
# Epoch   1 Batch  600/2154 - Train Accuracy: 0.7327, Validation Accuracy: 0.6605, Loss: 0.3412
# Epoch   1 Batch  650/2154 - Train Accuracy: 0.6750, Validation Accuracy: 0.6712, Loss: 0.3790
# Epoch   1 Batch  700/2154 - Train Accuracy: 0.6768, Validation Accuracy: 0.6527, Loss: 0.3533
# Epoch   1 Batch  750/2154 - Train Accuracy: 0.7203, Validation Accuracy: 0.6868, Loss: 0.3601
# Epoch   1 Batch  800/2154 - Train Accuracy: 0.7566, Validation Accuracy: 0.6825, Loss: 0.3272
# Epoch   1 Batch  850/2154 - Train Accuracy: 0.7406, Validation Accuracy: 0.6555, Loss: 0.3049
# Epoch   1 Batch  900/2154 - Train Accuracy: 0.7064, Validation Accuracy: 0.6868, Loss: 0.3540
# Epoch   1 Batch  950/2154 - Train Accuracy: 0.6760, Validation Accuracy: 0.6889, Loss: 0.3347
# Epoch   1 Batch 1000/2154 - Train Accuracy: 0.7344, Validation Accuracy: 0.6577, Loss: 0.2698
# Epoch   1 Batch 1050/2154 - Train Accuracy: 0.6820, Validation Accuracy: 0.6335, Loss: 0.3913
# Epoch   1 Batch 1100/2154 - Train Accuracy: 0.6766, Validation Accuracy: 0.7095, Loss: 0.3245
# Epoch   1 Batch 1150/2154 - Train Accuracy: 0.7385, Validation Accuracy: 0.6882, Loss: 0.2759
# Epoch   1 Batch 1200/2154 - Train Accuracy: 0.7352, Validation Accuracy: 0.7401, Loss: 0.3390
# Epoch   1 Batch 1250/2154 - Train Accuracy: 0.7422, Validation Accuracy: 0.7457, Loss: 0.2379
# Epoch   1 Batch 1300/2154 - Train Accuracy: 0.7344, Validation Accuracy: 0.7166, Loss: 0.2722
# Epoch   1 Batch 1350/2154 - Train Accuracy: 0.8180, Validation Accuracy: 0.6783, Loss: 0.2346
# Epoch   1 Batch 1400/2154 - Train Accuracy: 0.8141, Validation Accuracy: 0.7223, Loss: 0.2123
# Epoch   1 Batch 1450/2154 - Train Accuracy: 0.7862, Validation Accuracy: 0.7486, Loss: 0.2380
# Epoch   1 Batch 1500/2154 - Train Accuracy: 0.7377, Validation Accuracy: 0.7514, Loss: 0.2391
# Epoch   1 Batch 1550/2154 - Train Accuracy: 0.8070, Validation Accuracy: 0.7230, Loss: 0.2331
# Epoch   1 Batch 1600/2154 - Train Accuracy: 0.7391, Validation Accuracy: 0.6839, Loss: 0.2347
# Epoch   1 Batch 1650/2154 - Train Accuracy: 0.8423, Validation Accuracy: 0.7592, Loss: 0.2079
# Epoch   1 Batch 1700/2154 - Train Accuracy: 0.7937, Validation Accuracy: 0.7862, Loss: 0.1820
# Epoch   1 Batch 1750/2154 - Train Accuracy: 0.8555, Validation Accuracy: 0.7926, Loss: 0.1786
# Epoch   1 Batch 1800/2154 - Train Accuracy: 0.8383, Validation Accuracy: 0.7812, Loss: 0.1737
# Epoch   1 Batch 1850/2154 - Train Accuracy: 0.8651, Validation Accuracy: 0.7720, Loss: 0.2157
# Epoch   1 Batch 1900/2154 - Train Accuracy: 0.8695, Validation Accuracy: 0.7656, Loss: 0.1605
# Epoch   1 Batch 1950/2154 - Train Accuracy: 0.8484, Validation Accuracy: 0.7500, Loss: 0.1441
# Epoch   1 Batch 2000/2154 - Train Accuracy: 0.8500, Validation Accuracy: 0.8054, Loss: 0.1611
# Epoch   1 Batch 2050/2154 - Train Accuracy: 0.7558, Validation Accuracy: 0.7869, Loss: 0.1697
# Epoch   1 Batch 2100/2154 - Train Accuracy: 0.8586, Validation Accuracy: 0.7699, Loss: 0.1749
# Epoch   1 Batch 2150/2154 - Train Accuracy: 0.8371, Validation Accuracy: 0.7869, Loss: 0.1885
# Epoch   2 Batch   50/2154 - Train Accuracy: 0.8923, Validation Accuracy: 0.7933, Loss: 0.1470
# Epoch   2 Batch  100/2154 - Train Accuracy: 0.7396, Validation Accuracy: 0.7976, Loss: 0.1817
# Epoch   2 Batch  150/2154 - Train Accuracy: 0.8132, Validation Accuracy: 0.8395, Loss: 0.1428
# Epoch   2 Batch  200/2154 - Train Accuracy: 0.8703, Validation Accuracy: 0.8125, Loss: 0.1066
# Epoch   2 Batch  250/2154 - Train Accuracy: 0.8656, Validation Accuracy: 0.8075, Loss: 0.1418
# Epoch   2 Batch  300/2154 - Train Accuracy: 0.8553, Validation Accuracy: 0.8416, Loss: 0.1568
# Epoch   2 Batch  350/2154 - Train Accuracy: 0.8398, Validation Accuracy: 0.8445, Loss: 0.1510
# Epoch   2 Batch  400/2154 - Train Accuracy: 0.8320, Validation Accuracy: 0.8033, Loss: 0.1291
# Epoch   2 Batch  450/2154 - Train Accuracy: 0.8766, Validation Accuracy: 0.8395, Loss: 0.1203
# Epoch   2 Batch  500/2154 - Train Accuracy: 0.8717, Validation Accuracy: 0.8310, Loss: 0.1173
# Epoch   2 Batch  550/2154 - Train Accuracy: 0.8876, Validation Accuracy: 0.8175, Loss: 0.1306
# Epoch   2 Batch  600/2154 - Train Accuracy: 0.9276, Validation Accuracy: 0.8459, Loss: 0.0904
# Epoch   2 Batch  650/2154 - Train Accuracy: 0.8734, Validation Accuracy: 0.8565, Loss: 0.1306
# Epoch   2 Batch  700/2154 - Train Accuracy: 0.6768, Validation Accuracy: 0.6783, Loss: 0.7882
# Epoch   2 Batch  750/2154 - Train Accuracy: 0.8516, Validation Accuracy: 0.8196, Loss: 0.1563
# Epoch   2 Batch  800/2154 - Train Accuracy: 0.8717, Validation Accuracy: 0.8104, Loss: 0.1212
# Epoch   2 Batch  850/2154 - Train Accuracy: 0.8828, Validation Accuracy: 0.8580, Loss: 0.0930
# Epoch   2 Batch  900/2154 - Train Accuracy: 0.8627, Validation Accuracy: 0.8359, Loss: 0.1355
# Epoch   2 Batch  950/2154 - Train Accuracy: 0.8438, Validation Accuracy: 0.8778, Loss: 0.1109
# Epoch   2 Batch 1000/2154 - Train Accuracy: 0.8757, Validation Accuracy: 0.8643, Loss: 0.0786
# Epoch   2 Batch 1050/2154 - Train Accuracy: 0.9008, Validation Accuracy: 0.7933, Loss: 0.1126
# Epoch   2 Batch 1100/2154 - Train Accuracy: 0.8805, Validation Accuracy: 0.8374, Loss: 0.1157
# Epoch   2 Batch 1150/2154 - Train Accuracy: 0.8816, Validation Accuracy: 0.8473, Loss: 0.1009
# Epoch   2 Batch 1200/2154 - Train Accuracy: 0.8725, Validation Accuracy: 0.8970, Loss: 0.1343
# Epoch   2 Batch 1250/2154 - Train Accuracy: 0.9039, Validation Accuracy: 0.8381, Loss: 0.0829
# Epoch   2 Batch 1300/2154 - Train Accuracy: 0.8234, Validation Accuracy: 0.8672, Loss: 0.1124
# Epoch   2 Batch 1350/2154 - Train Accuracy: 0.8844, Validation Accuracy: 0.8161, Loss: 0.0912
# Epoch   2 Batch 1400/2154 - Train Accuracy: 0.8882, Validation Accuracy: 0.8622, Loss: 0.0802
# Epoch   2 Batch 1450/2154 - Train Accuracy: 0.8923, Validation Accuracy: 0.8736, Loss: 0.0950
# Epoch   2 Batch 1500/2154 - Train Accuracy: 0.9104, Validation Accuracy: 0.8906, Loss: 0.0846
# Epoch   2 Batch 1550/2154 - Train Accuracy: 0.8883, Validation Accuracy: 0.8636, Loss: 0.1095
# Epoch   2 Batch 1600/2154 - Train Accuracy: 0.8578, Validation Accuracy: 0.8523, Loss: 0.1054
# Epoch   2 Batch 1650/2154 - Train Accuracy: 0.9100, Validation Accuracy: 0.9048, Loss: 0.0818
# Epoch   2 Batch 1700/2154 - Train Accuracy: 0.8820, Validation Accuracy: 0.9048, Loss: 0.0853
# Epoch   2 Batch 1750/2154 - Train Accuracy: 0.9187, Validation Accuracy: 0.8537, Loss: 0.0788
# Epoch   2 Batch 1800/2154 - Train Accuracy: 0.9062, Validation Accuracy: 0.8786, Loss: 0.0711
# Epoch   2 Batch 1850/2154 - Train Accuracy: 0.9260, Validation Accuracy: 0.8686, Loss: 0.1214
# Epoch   2 Batch 1900/2154 - Train Accuracy: 0.9422, Validation Accuracy: 0.8707, Loss: 0.0752
# Epoch   2 Batch 1950/2154 - Train Accuracy: 0.9359, Validation Accuracy: 0.8686, Loss: 0.0613
# Epoch   2 Batch 2000/2154 - Train Accuracy: 0.9047, Validation Accuracy: 0.8849, Loss: 0.0742
# Epoch   2 Batch 2050/2154 - Train Accuracy: 0.8577, Validation Accuracy: 0.8714, Loss: 0.0880
# Epoch   2 Batch 2100/2154 - Train Accuracy: 0.8938, Validation Accuracy: 0.8565, Loss: 0.0855
# Epoch   2 Batch 2150/2154 - Train Accuracy: 0.9219, Validation Accuracy: 0.9027, Loss: 0.1159
# Epoch   3 Batch   50/2154 - Train Accuracy: 0.9071, Validation Accuracy: 0.8786, Loss: 0.0786
# Epoch   3 Batch  100/2154 - Train Accuracy: 0.8690, Validation Accuracy: 0.8984, Loss: 0.1140
# Epoch   3 Batch  150/2154 - Train Accuracy: 0.9115, Validation Accuracy: 0.8956, Loss: 0.0770
# Epoch   3 Batch  200/2154 - Train Accuracy: 0.9477, Validation Accuracy: 0.9276, Loss: 0.0462
# Epoch   3 Batch  250/2154 - Train Accuracy: 0.9219, Validation Accuracy: 0.9084, Loss: 0.0780
# Epoch   3 Batch  300/2154 - Train Accuracy: 0.9441, Validation Accuracy: 0.8878, Loss: 0.0824
# Epoch   3 Batch  350/2154 - Train Accuracy: 0.9219, Validation Accuracy: 0.8942, Loss: 0.0758
# Epoch   3 Batch  400/2154 - Train Accuracy: 0.9234, Validation Accuracy: 0.9027, Loss: 0.0654
# Epoch   3 Batch  450/2154 - Train Accuracy: 0.9289, Validation Accuracy: 0.9077, Loss: 0.0591
# Epoch   3 Batch  500/2154 - Train Accuracy: 0.9309, Validation Accuracy: 0.8814, Loss: 0.0653
# Epoch   3 Batch  550/2154 - Train Accuracy: 0.9137, Validation Accuracy: 0.8750, Loss: 0.0729
# Epoch   3 Batch  600/2154 - Train Accuracy: 0.9079, Validation Accuracy: 0.8942, Loss: 0.0590
# Epoch   3 Batch  650/2154 - Train Accuracy: 0.8711, Validation Accuracy: 0.8956, Loss: 0.0713
# Epoch   3 Batch  700/2154 - Train Accuracy: 0.8602, Validation Accuracy: 0.9318, Loss: 0.0735
# Epoch   3 Batch  750/2154 - Train Accuracy: 0.9016, Validation Accuracy: 0.9183, Loss: 0.0770
# Epoch   3 Batch  800/2154 - Train Accuracy: 0.9252, Validation Accuracy: 0.8786, Loss: 0.0660
# Epoch   3 Batch  850/2154 - Train Accuracy: 0.8891, Validation Accuracy: 0.9190, Loss: 0.0586
# Epoch   3 Batch  900/2154 - Train Accuracy: 0.9219, Validation Accuracy: 0.8679, Loss: 0.0794
# Epoch   3 Batch  950/2154 - Train Accuracy: 0.8454, Validation Accuracy: 0.9134, Loss: 0.0839
# Epoch   3 Batch 1000/2154 - Train Accuracy: 0.9115, Validation Accuracy: 0.8935, Loss: 0.0440
# Epoch   3 Batch 1050/2154 - Train Accuracy: 0.9023, Validation Accuracy: 0.9034, Loss: 0.0760
# Epoch   3 Batch 1100/2154 - Train Accuracy: 0.9133, Validation Accuracy: 0.9013, Loss: 0.0776
# Epoch   3 Batch 1150/2154 - Train Accuracy: 0.9145, Validation Accuracy: 0.8942, Loss: 0.0976
# Epoch   3 Batch 1200/2154 - Train Accuracy: 0.8783, Validation Accuracy: 0.9034, Loss: 0.0886
# Epoch   3 Batch 1250/2154 - Train Accuracy: 0.9023, Validation Accuracy: 0.8857, Loss: 0.0713
# Epoch   3 Batch 1300/2154 - Train Accuracy: 0.8656, Validation Accuracy: 0.9020, Loss: 0.0892
# Epoch   3 Batch 1350/2154 - Train Accuracy: 0.8945, Validation Accuracy: 0.8736, Loss: 0.1072
# Epoch   3 Batch 1400/2154 - Train Accuracy: 0.9564, Validation Accuracy: 0.9034, Loss: 0.0632
# Epoch   3 Batch 1450/2154 - Train Accuracy: 0.9095, Validation Accuracy: 0.9084, Loss: 0.0595
# Epoch   3 Batch 1500/2154 - Train Accuracy: 0.9268, Validation Accuracy: 0.9077, Loss: 0.0528
# Epoch   3 Batch 1550/2154 - Train Accuracy: 0.8914, Validation Accuracy: 0.8580, Loss: 0.0798
# Epoch   3 Batch 1600/2154 - Train Accuracy: 0.8812, Validation Accuracy: 0.9297, Loss: 0.0690
# Epoch   3 Batch 1650/2154 - Train Accuracy: 0.9368, Validation Accuracy: 0.9680, Loss: 0.0593
# Epoch   3 Batch 1700/2154 - Train Accuracy: 0.9195, Validation Accuracy: 0.9119, Loss: 0.0460
# Epoch   3 Batch 1750/2154 - Train Accuracy: 0.9211, Validation Accuracy: 0.9070, Loss: 0.0504
# Epoch   3 Batch 1800/2154 - Train Accuracy: 0.8945, Validation Accuracy: 0.8580, Loss: 0.0605
# Epoch   3 Batch 1850/2154 - Train Accuracy: 0.9145, Validation Accuracy: 0.9141, Loss: 0.0926
# Epoch   3 Batch 1900/2154 - Train Accuracy: 0.9414, Validation Accuracy: 0.8942, Loss: 0.0480
# Epoch   3 Batch 1950/2154 - Train Accuracy: 0.9547, Validation Accuracy: 0.9425, Loss: 0.0397
# Epoch   3 Batch 2000/2154 - Train Accuracy: 0.9289, Validation Accuracy: 0.9020, Loss: 0.0543
# Epoch   3 Batch 2050/2154 - Train Accuracy: 0.8840, Validation Accuracy: 0.9261, Loss: 0.0604
# Epoch   3 Batch 2100/2154 - Train Accuracy: 0.9164, Validation Accuracy: 0.9304, Loss: 0.0404
# Epoch   3 Batch 2150/2154 - Train Accuracy: 0.9665, Validation Accuracy: 0.9403, Loss: 0.0676
# Epoch   4 Batch   50/2154 - Train Accuracy: 0.9433, Validation Accuracy: 0.9361, Loss: 0.0651
# Epoch   4 Batch  100/2154 - Train Accuracy: 0.9249, Validation Accuracy: 0.9439, Loss: 0.0800
# Epoch   4 Batch  150/2154 - Train Accuracy: 0.9479, Validation Accuracy: 0.8949, Loss: 0.0583
# Epoch   4 Batch  200/2154 - Train Accuracy: 0.9609, Validation Accuracy: 0.8864, Loss: 0.0393
# Epoch   4 Batch  250/2154 - Train Accuracy: 0.8953, Validation Accuracy: 0.9332, Loss: 0.0764
# Epoch   4 Batch  300/2154 - Train Accuracy: 0.9622, Validation Accuracy: 0.9347, Loss: 0.0661
# Epoch   4 Batch  350/2154 - Train Accuracy: 0.9281, Validation Accuracy: 0.9432, Loss: 0.0525
# Epoch   4 Batch  400/2154 - Train Accuracy: 0.9336, Validation Accuracy: 0.9439, Loss: 0.0519
# Epoch   4 Batch  450/2154 - Train Accuracy: 0.9586, Validation Accuracy: 0.9290, Loss: 0.0446
# Epoch   4 Batch  500/2154 - Train Accuracy: 0.9646, Validation Accuracy: 0.9425, Loss: 0.0415
# Epoch   4 Batch  550/2154 - Train Accuracy: 0.9241, Validation Accuracy: 0.8984, Loss: 0.0514
# Epoch   4 Batch  600/2154 - Train Accuracy: 0.9465, Validation Accuracy: 0.9311, Loss: 0.0410
# Epoch   4 Batch  650/2154 - Train Accuracy: 0.8672, Validation Accuracy: 0.8984, Loss: 0.0590
# Epoch   4 Batch  700/2154 - Train Accuracy: 0.9260, Validation Accuracy: 0.9311, Loss: 0.0613
# Epoch   4 Batch  750/2154 - Train Accuracy: 0.9039, Validation Accuracy: 0.9361, Loss: 0.0840
# Epoch   4 Batch  800/2154 - Train Accuracy: 0.9260, Validation Accuracy: 0.9219, Loss: 0.0453
# Epoch   4 Batch  850/2154 - Train Accuracy: 0.9070, Validation Accuracy: 0.9375, Loss: 0.0457
# Epoch   4 Batch  900/2154 - Train Accuracy: 0.9474, Validation Accuracy: 0.8892, Loss: 0.0576
# Epoch   4 Batch  950/2154 - Train Accuracy: 0.9260, Validation Accuracy: 0.9375, Loss: 0.0510
# Epoch   4 Batch 1000/2154 - Train Accuracy: 0.9159, Validation Accuracy: 0.9318, Loss: 0.0415
# Epoch   4 Batch 1050/2154 - Train Accuracy: 0.9055, Validation Accuracy: 0.8899, Loss: 0.0679
# Epoch   4 Batch 1100/2154 - Train Accuracy: 0.9109, Validation Accuracy: 0.9169, Loss: 0.0617
# Epoch   4 Batch 1150/2154 - Train Accuracy: 0.9285, Validation Accuracy: 0.9389, Loss: 0.0641
# Epoch   4 Batch 1200/2154 - Train Accuracy: 0.9285, Validation Accuracy: 0.9482, Loss: 0.0886
# Epoch   4 Batch 1250/2154 - Train Accuracy: 0.9602, Validation Accuracy: 0.9318, Loss: 0.0406
# Epoch   4 Batch 1300/2154 - Train Accuracy: 0.9227, Validation Accuracy: 0.9517, Loss: 0.0519
# Epoch   4 Batch 1350/2154 - Train Accuracy: 0.9406, Validation Accuracy: 0.9432, Loss: 0.0435
# Epoch   4 Batch 1400/2154 - Train Accuracy: 0.9383, Validation Accuracy: 0.9219, Loss: 0.0383
# Epoch   4 Batch 1450/2154 - Train Accuracy: 0.9095, Validation Accuracy: 0.9268, Loss: 0.0475
# Epoch   4 Batch 1500/2154 - Train Accuracy: 0.9449, Validation Accuracy: 0.9375, Loss: 0.0304
# Epoch   4 Batch 1550/2154 - Train Accuracy: 0.9680, Validation Accuracy: 0.9375, Loss: 0.0516
# Epoch   4 Batch 1600/2154 - Train Accuracy: 0.8977, Validation Accuracy: 0.9318, Loss: 0.0500
# Epoch   4 Batch 1650/2154 - Train Accuracy: 0.9360, Validation Accuracy: 0.9595, Loss: 0.0516
# Epoch   4 Batch 1700/2154 - Train Accuracy: 0.9266, Validation Accuracy: 0.9567, Loss: 0.0408
# Epoch   4 Batch 1750/2154 - Train Accuracy: 0.9133, Validation Accuracy: 0.9219, Loss: 0.0437
# Epoch   4 Batch 1800/2154 - Train Accuracy: 0.9578, Validation Accuracy: 0.9212, Loss: 0.0569
# Epoch   4 Batch 1850/2154 - Train Accuracy: 0.9285, Validation Accuracy: 0.9538, Loss: 0.0680
# Epoch   4 Batch 1900/2154 - Train Accuracy: 0.9633, Validation Accuracy: 0.9261, Loss: 0.0330
# Epoch   4 Batch 1950/2154 - Train Accuracy: 0.9695, Validation Accuracy: 0.9119, Loss: 0.0293
# Epoch   4 Batch 2000/2154 - Train Accuracy: 0.9250, Validation Accuracy: 0.8920, Loss: 0.0621
# Epoch   4 Batch 2050/2154 - Train Accuracy: 0.9169, Validation Accuracy: 0.9304, Loss: 0.0596
# Epoch   4 Batch 2100/2154 - Train Accuracy: 0.9500, Validation Accuracy: 0.9318, Loss: 0.0408
# Epoch   4 Batch 2150/2154 - Train Accuracy: 0.9561, Validation Accuracy: 0.9418, Loss: 0.0434
# Epoch   5 Batch   50/2154 - Train Accuracy: 0.9285, Validation Accuracy: 0.9439, Loss: 0.0592
# Epoch   5 Batch  100/2154 - Train Accuracy: 0.9092, Validation Accuracy: 0.9389, Loss: 0.0921
# Epoch   5 Batch  150/2154 - Train Accuracy: 0.9494, Validation Accuracy: 0.9616, Loss: 0.0359
# Epoch   5 Batch  200/2154 - Train Accuracy: 0.9453, Validation Accuracy: 0.9446, Loss: 0.0285
# Epoch   5 Batch  250/2154 - Train Accuracy: 0.9461, Validation Accuracy: 0.9666, Loss: 0.0499
# Epoch   5 Batch  300/2154 - Train Accuracy: 0.9638, Validation Accuracy: 0.9567, Loss: 0.0444
# Epoch   5 Batch  350/2154 - Train Accuracy: 0.9320, Validation Accuracy: 0.9432, Loss: 0.0491
# Epoch   5 Batch  400/2154 - Train Accuracy: 0.9313, Validation Accuracy: 0.9524, Loss: 0.0407
# Epoch   5 Batch  450/2154 - Train Accuracy: 0.9266, Validation Accuracy: 0.9190, Loss: 0.0337
# Epoch   5 Batch  500/2154 - Train Accuracy: 0.9844, Validation Accuracy: 0.9531, Loss: 0.0396
# Epoch   5 Batch  550/2154 - Train Accuracy: 0.9033, Validation Accuracy: 0.9588, Loss: 0.0450
# Epoch   5 Batch  600/2154 - Train Accuracy: 0.9638, Validation Accuracy: 0.9517, Loss: 0.0307
# Epoch   5 Batch  650/2154 - Train Accuracy: 0.9062, Validation Accuracy: 0.9652, Loss: 0.0442
# Epoch   5 Batch  700/2154 - Train Accuracy: 0.9597, Validation Accuracy: 0.9524, Loss: 0.0354
# Epoch   5 Batch  750/2154 - Train Accuracy: 0.9320, Validation Accuracy: 0.9666, Loss: 0.0414
# Epoch   5 Batch  800/2154 - Train Accuracy: 0.9235, Validation Accuracy: 0.9652, Loss: 0.0312
# Epoch   5 Batch  850/2154 - Train Accuracy: 0.9680, Validation Accuracy: 0.9474, Loss: 0.0262
# Epoch   5 Batch  900/2154 - Train Accuracy: 0.9383, Validation Accuracy: 0.9382, Loss: 0.0455
# Epoch   5 Batch  950/2154 - Train Accuracy: 0.9523, Validation Accuracy: 0.9538, Loss: 0.0435
# Epoch   5 Batch 1000/2154 - Train Accuracy: 0.9472, Validation Accuracy: 0.9503, Loss: 0.0304
# Epoch   5 Batch 1050/2154 - Train Accuracy: 0.9320, Validation Accuracy: 0.9517, Loss: 0.0522
# Epoch   5 Batch 1100/2154 - Train Accuracy: 0.9531, Validation Accuracy: 0.9425, Loss: 0.0422
# Epoch   5 Batch 1150/2154 - Train Accuracy: 0.9449, Validation Accuracy: 0.9482, Loss: 0.0402
# Epoch   5 Batch 1200/2154 - Train Accuracy: 0.9186, Validation Accuracy: 0.9638, Loss: 0.0655
# Epoch   5 Batch 1250/2154 - Train Accuracy: 0.9320, Validation Accuracy: 0.9148, Loss: 0.0334
# Epoch   5 Batch 1300/2154 - Train Accuracy: 0.9055, Validation Accuracy: 0.9034, Loss: 0.1101
# Epoch   5 Batch 1350/2154 - Train Accuracy: 0.9320, Validation Accuracy: 0.9226, Loss: 0.0649
# Epoch   5 Batch 1400/2154 - Train Accuracy: 0.9449, Validation Accuracy: 0.9453, Loss: 0.0422
# Epoch   5 Batch 1450/2154 - Train Accuracy: 0.9219, Validation Accuracy: 0.9616, Loss: 0.0440
# Epoch   5 Batch 1500/2154 - Train Accuracy: 0.9655, Validation Accuracy: 0.9624, Loss: 0.0299
# Epoch   5 Batch 1550/2154 - Train Accuracy: 0.9750, Validation Accuracy: 0.9482, Loss: 0.0398
# Epoch   5 Batch 1600/2154 - Train Accuracy: 0.9109, Validation Accuracy: 0.9425, Loss: 0.0407
# Epoch   5 Batch 1650/2154 - Train Accuracy: 0.9568, Validation Accuracy: 0.9574, Loss: 0.0389
# Epoch   5 Batch 1700/2154 - Train Accuracy: 0.9313, Validation Accuracy: 0.9680, Loss: 0.0374
# Epoch   5 Batch 1750/2154 - Train Accuracy: 0.9297, Validation Accuracy: 0.9545, Loss: 0.0396
# Epoch   5 Batch 1800/2154 - Train Accuracy: 0.9570, Validation Accuracy: 0.9339, Loss: 0.0276
# Epoch   5 Batch 1850/2154 - Train Accuracy: 0.9539, Validation Accuracy: 0.9709, Loss: 0.0516
# Epoch   5 Batch 1900/2154 - Train Accuracy: 0.9570, Validation Accuracy: 0.9496, Loss: 0.0253
# Epoch   5 Batch 1950/2154 - Train Accuracy: 0.9750, Validation Accuracy: 0.9673, Loss: 0.0175
# Epoch   5 Batch 2000/2154 - Train Accuracy: 0.9641, Validation Accuracy: 0.9474, Loss: 0.0340
# Epoch   5 Batch 2050/2154 - Train Accuracy: 0.9120, Validation Accuracy: 0.9474, Loss: 0.0415
# Epoch   5 Batch 2100/2154 - Train Accuracy: 0.9672, Validation Accuracy: 0.9524, Loss: 0.0250
# Epoch   5 Batch 2150/2154 - Train Accuracy: 0.9792, Validation Accuracy: 0.9631, Loss: 0.0372
# Epoch   6 Batch   50/2154 - Train Accuracy: 0.9342, Validation Accuracy: 0.9233, Loss: 0.0594
# Epoch   6 Batch  100/2154 - Train Accuracy: 0.9070, Validation Accuracy: 0.9041, Loss: 0.0650
# Epoch   6 Batch  150/2154 - Train Accuracy: 0.9628, Validation Accuracy: 0.9567, Loss: 0.0356
# Epoch   6 Batch  200/2154 - Train Accuracy: 0.9648, Validation Accuracy: 0.9545, Loss: 0.0198
# Epoch   6 Batch  250/2154 - Train Accuracy: 0.9719, Validation Accuracy: 0.9091, Loss: 0.0464
# Epoch   6 Batch  300/2154 - Train Accuracy: 0.9507, Validation Accuracy: 0.9666, Loss: 0.0400
# Epoch   6 Batch  350/2154 - Train Accuracy: 0.9406, Validation Accuracy: 0.9744, Loss: 0.0334
# Epoch   6 Batch  400/2154 - Train Accuracy: 0.9391, Validation Accuracy: 0.9482, Loss: 0.0364
# Epoch   6 Batch  450/2154 - Train Accuracy: 0.9812, Validation Accuracy: 0.9439, Loss: 0.0234
# Epoch   6 Batch  500/2154 - Train Accuracy: 0.9778, Validation Accuracy: 0.9105, Loss: 0.0325
# Epoch   6 Batch  550/2154 - Train Accuracy: 0.9539, Validation Accuracy: 0.9361, Loss: 0.0325
# Epoch   6 Batch  600/2154 - Train Accuracy: 0.9762, Validation Accuracy: 0.9297, Loss: 0.0268
# Epoch   6 Batch  650/2154 - Train Accuracy: 0.9102, Validation Accuracy: 0.9283, Loss: 0.0393
# Epoch   6 Batch  700/2154 - Train Accuracy: 0.9646, Validation Accuracy: 0.9403, Loss: 0.0324
# Epoch   6 Batch  750/2154 - Train Accuracy: 0.9508, Validation Accuracy: 0.9489, Loss: 0.0386
# Epoch   6 Batch  800/2154 - Train Accuracy: 0.9383, Validation Accuracy: 0.9766, Loss: 0.0281
# Epoch   6 Batch  850/2154 - Train Accuracy: 0.9680, Validation Accuracy: 0.9467, Loss: 0.0309
# Epoch   6 Batch  900/2154 - Train Accuracy: 0.9646, Validation Accuracy: 0.9411, Loss: 0.0479
# Epoch   6 Batch  950/2154 - Train Accuracy: 0.9729, Validation Accuracy: 0.9446, Loss: 0.0315
# Epoch   6 Batch 1000/2154 - Train Accuracy: 0.9561, Validation Accuracy: 0.9609, Loss: 0.0269
# Epoch   6 Batch 1050/2154 - Train Accuracy: 0.8906, Validation Accuracy: 0.9283, Loss: 0.0555
# Epoch   6 Batch 1100/2154 - Train Accuracy: 0.9039, Validation Accuracy: 0.9609, Loss: 0.0462
# Epoch   6 Batch 1150/2154 - Train Accuracy: 0.9515, Validation Accuracy: 0.9354, Loss: 0.0492
# Epoch   6 Batch 1200/2154 - Train Accuracy: 0.9474, Validation Accuracy: 0.9688, Loss: 0.0605
# Epoch   6 Batch 1250/2154 - Train Accuracy: 0.9570, Validation Accuracy: 0.9205, Loss: 0.0258
# Epoch   6 Batch 1300/2154 - Train Accuracy: 0.9734, Validation Accuracy: 0.9574, Loss: 0.0312
# Epoch   6 Batch 1350/2154 - Train Accuracy: 0.9641, Validation Accuracy: 0.9396, Loss: 0.0316
# Epoch   6 Batch 1400/2154 - Train Accuracy: 0.9391, Validation Accuracy: 0.9432, Loss: 0.0273
# Epoch   6 Batch 1450/2154 - Train Accuracy: 0.9375, Validation Accuracy: 0.9872, Loss: 0.0362
# Epoch   6 Batch 1500/2154 - Train Accuracy: 0.9819, Validation Accuracy: 0.9624, Loss: 0.0157
# Epoch   6 Batch 1550/2154 - Train Accuracy: 0.9680, Validation Accuracy: 0.9538, Loss: 0.0346
# Epoch   6 Batch 1600/2154 - Train Accuracy: 0.9523, Validation Accuracy: 0.9652, Loss: 0.0282
# Epoch   6 Batch 1650/2154 - Train Accuracy: 0.9554, Validation Accuracy: 0.9815, Loss: 0.0361
# Epoch   6 Batch 1700/2154 - Train Accuracy: 0.9586, Validation Accuracy: 0.9602, Loss: 0.0244
# Epoch   6 Batch 1750/2154 - Train Accuracy: 0.9117, Validation Accuracy: 0.9844, Loss: 0.0334
# Epoch   6 Batch 1800/2154 - Train Accuracy: 0.9383, Validation Accuracy: 0.9382, Loss: 0.0409
# Epoch   6 Batch 1850/2154 - Train Accuracy: 0.9605, Validation Accuracy: 0.9581, Loss: 0.0674
# Epoch   6 Batch 1900/2154 - Train Accuracy: 0.9586, Validation Accuracy: 0.9737, Loss: 0.0225
# Epoch   6 Batch 1950/2154 - Train Accuracy: 0.9594, Validation Accuracy: 0.9915, Loss: 0.0226
# Epoch   6 Batch 2000/2154 - Train Accuracy: 0.9641, Validation Accuracy: 0.9332, Loss: 0.0314
# Epoch   6 Batch 2050/2154 - Train Accuracy: 0.9071, Validation Accuracy: 0.9482, Loss: 0.0438
# Epoch   6 Batch 2100/2154 - Train Accuracy: 0.9570, Validation Accuracy: 0.9354, Loss: 0.0277
# Epoch   6 Batch 2150/2154 - Train Accuracy: 0.9702, Validation Accuracy: 0.9695, Loss: 0.0354
# Epoch   7 Batch   50/2154 - Train Accuracy: 0.9326, Validation Accuracy: 0.9396, Loss: 0.0486
# Epoch   7 Batch  100/2154 - Train Accuracy: 0.9427, Validation Accuracy: 0.9339, Loss: 0.0489
# Epoch   7 Batch  150/2154 - Train Accuracy: 0.9688, Validation Accuracy: 0.9638, Loss: 0.0246
# Epoch   7 Batch  200/2154 - Train Accuracy: 0.9766, Validation Accuracy: 0.9822, Loss: 0.0174
# Epoch   7 Batch  250/2154 - Train Accuracy: 0.9633, Validation Accuracy: 0.9496, Loss: 0.0314
# Epoch   7 Batch  300/2154 - Train Accuracy: 0.9646, Validation Accuracy: 0.9545, Loss: 0.0408
# Epoch   7 Batch  350/2154 - Train Accuracy: 0.9484, Validation Accuracy: 0.9290, Loss: 0.0274
# Epoch   7 Batch  400/2154 - Train Accuracy: 0.9594, Validation Accuracy: 0.9460, Loss: 0.0336
# Epoch   7 Batch  450/2154 - Train Accuracy: 0.9906, Validation Accuracy: 0.9574, Loss: 0.0156
# Epoch   7 Batch  500/2154 - Train Accuracy: 0.9770, Validation Accuracy: 0.9574, Loss: 0.0231
# Epoch   7 Batch  550/2154 - Train Accuracy: 0.9487, Validation Accuracy: 0.9595, Loss: 0.0248
# Epoch   7 Batch  600/2154 - Train Accuracy: 0.9885, Validation Accuracy: 0.9645, Loss: 0.0192
# Epoch   7 Batch  650/2154 - Train Accuracy: 0.9234, Validation Accuracy: 0.9560, Loss: 0.0322
# Epoch   7 Batch  700/2154 - Train Accuracy: 0.9951, Validation Accuracy: 0.9389, Loss: 0.0262
# Epoch   7 Batch  750/2154 - Train Accuracy: 0.9641, Validation Accuracy: 0.9773, Loss: 0.0326
# Epoch   7 Batch  800/2154 - Train Accuracy: 0.9605, Validation Accuracy: 0.9702, Loss: 0.0204
# Epoch   7 Batch  850/2154 - Train Accuracy: 0.9570, Validation Accuracy: 0.9609, Loss: 0.0257
# Epoch   7 Batch  900/2154 - Train Accuracy: 0.9671, Validation Accuracy: 0.9517, Loss: 0.0331
# Epoch   7 Batch  950/2154 - Train Accuracy: 0.9762, Validation Accuracy: 0.9510, Loss: 0.0213
# Epoch   7 Batch 1000/2154 - Train Accuracy: 0.9606, Validation Accuracy: 0.9830, Loss: 0.0217
# Epoch   7 Batch 1050/2154 - Train Accuracy: 0.9359, Validation Accuracy: 0.9581, Loss: 0.0393
# Epoch   7 Batch 1100/2154 - Train Accuracy: 0.9703, Validation Accuracy: 0.9730, Loss: 0.0274
# Epoch   7 Batch 1150/2154 - Train Accuracy: 0.9877, Validation Accuracy: 0.9638, Loss: 0.0283
# Epoch   7 Batch 1200/2154 - Train Accuracy: 0.9465, Validation Accuracy: 0.9616, Loss: 0.0457
# Epoch   7 Batch 1250/2154 - Train Accuracy: 0.9531, Validation Accuracy: 0.9638, Loss: 0.0205
# Epoch   7 Batch 1300/2154 - Train Accuracy: 0.9797, Validation Accuracy: 0.9489, Loss: 0.0291
# Epoch   7 Batch 1350/2154 - Train Accuracy: 0.9516, Validation Accuracy: 0.9226, Loss: 0.0313
# Epoch   7 Batch 1400/2154 - Train Accuracy: 0.9696, Validation Accuracy: 0.9318, Loss: 0.0263
# Epoch   7 Batch 1450/2154 - Train Accuracy: 0.9745, Validation Accuracy: 0.9716, Loss: 0.0323
# Epoch   7 Batch 1500/2154 - Train Accuracy: 0.9910, Validation Accuracy: 0.9616, Loss: 0.0168
# Epoch   7 Batch 1550/2154 - Train Accuracy: 0.9812, Validation Accuracy: 0.9545, Loss: 0.0267
# Epoch   7 Batch 1600/2154 - Train Accuracy: 0.9555, Validation Accuracy: 0.9822, Loss: 0.0300
# Epoch   7 Batch 1650/2154 - Train Accuracy: 0.9829, Validation Accuracy: 0.9872, Loss: 0.0239
# Epoch   7 Batch 1700/2154 - Train Accuracy: 0.9430, Validation Accuracy: 0.9801, Loss: 0.0239
# Epoch   7 Batch 1750/2154 - Train Accuracy: 0.9500, Validation Accuracy: 0.9382, Loss: 0.0325
# Epoch   7 Batch 1800/2154 - Train Accuracy: 0.9258, Validation Accuracy: 0.9453, Loss: 0.0275
# Epoch   7 Batch 1850/2154 - Train Accuracy: 0.9704, Validation Accuracy: 0.9631, Loss: 0.0399
# Epoch   7 Batch 1900/2154 - Train Accuracy: 0.9805, Validation Accuracy: 0.9659, Loss: 0.0147
# Epoch   7 Batch 1950/2154 - Train Accuracy: 0.9680, Validation Accuracy: 0.9602, Loss: 0.0146
# Epoch   7 Batch 2000/2154 - Train Accuracy: 0.9664, Validation Accuracy: 0.9403, Loss: 0.0256
# Epoch   7 Batch 2050/2154 - Train Accuracy: 0.9145, Validation Accuracy: 0.9787, Loss: 0.0308
# Epoch   7 Batch 2100/2154 - Train Accuracy: 0.9805, Validation Accuracy: 0.9631, Loss: 0.0204
# Epoch   7 Batch 2150/2154 - Train Accuracy: 0.9710, Validation Accuracy: 0.9652, Loss: 0.0265
# Epoch   8 Batch   50/2154 - Train Accuracy: 0.9391, Validation Accuracy: 0.9688, Loss: 0.0381
# Epoch   8 Batch  100/2154 - Train Accuracy: 0.9539, Validation Accuracy: 0.9354, Loss: 0.0470
# Epoch   8 Batch  150/2154 - Train Accuracy: 0.9680, Validation Accuracy: 0.9517, Loss: 0.0248
# Epoch   8 Batch  200/2154 - Train Accuracy: 0.9945, Validation Accuracy: 0.9538, Loss: 0.0165
# Epoch   8 Batch  250/2154 - Train Accuracy: 0.9609, Validation Accuracy: 0.9574, Loss: 0.0257
# Epoch   8 Batch  300/2154 - Train Accuracy: 0.9910, Validation Accuracy: 0.9240, Loss: 0.0421
# Epoch   8 Batch  350/2154 - Train Accuracy: 0.9500, Validation Accuracy: 0.9496, Loss: 0.0363
# Epoch   8 Batch  400/2154 - Train Accuracy: 0.9563, Validation Accuracy: 0.9688, Loss: 0.0356
# Epoch   8 Batch  450/2154 - Train Accuracy: 0.9805, Validation Accuracy: 0.9560, Loss: 0.0271
# Epoch   8 Batch  500/2154 - Train Accuracy: 0.9844, Validation Accuracy: 0.9574, Loss: 0.0196
# Epoch   8 Batch  550/2154 - Train Accuracy: 0.9554, Validation Accuracy: 0.9744, Loss: 0.0201
# Epoch   8 Batch  600/2154 - Train Accuracy: 0.9860, Validation Accuracy: 0.9432, Loss: 0.0178
# Epoch   8 Batch  650/2154 - Train Accuracy: 0.9492, Validation Accuracy: 0.9688, Loss: 0.0254
# Epoch   8 Batch  700/2154 - Train Accuracy: 0.9704, Validation Accuracy: 0.9503, Loss: 0.0175
# Epoch   8 Batch  750/2154 - Train Accuracy: 0.9859, Validation Accuracy: 0.9403, Loss: 0.0209
# Epoch   8 Batch  800/2154 - Train Accuracy: 0.9745, Validation Accuracy: 0.9609, Loss: 0.0167
# Epoch   8 Batch  850/2154 - Train Accuracy: 0.9766, Validation Accuracy: 0.9702, Loss: 0.0166
# Epoch   8 Batch  900/2154 - Train Accuracy: 0.9696, Validation Accuracy: 0.9482, Loss: 0.0283
# Epoch   8 Batch  950/2154 - Train Accuracy: 0.9671, Validation Accuracy: 0.9666, Loss: 0.0164
# Epoch   8 Batch 1000/2154 - Train Accuracy: 0.9606, Validation Accuracy: 0.9716, Loss: 0.0266
# Epoch   8 Batch 1050/2154 - Train Accuracy: 0.9414, Validation Accuracy: 0.9318, Loss: 0.0381
# Epoch   8 Batch 1100/2154 - Train Accuracy: 0.9703, Validation Accuracy: 0.9418, Loss: 0.0283
# Epoch   8 Batch 1150/2154 - Train Accuracy: 0.9770, Validation Accuracy: 0.9574, Loss: 0.0233
# Epoch   8 Batch 1200/2154 - Train Accuracy: 0.9539, Validation Accuracy: 0.9673, Loss: 0.0496
# Epoch   8 Batch 1250/2154 - Train Accuracy: 0.9875, Validation Accuracy: 0.9183, Loss: 0.0140
# Epoch   8 Batch 1300/2154 - Train Accuracy: 0.9820, Validation Accuracy: 0.9673, Loss: 0.0170
# Epoch   8 Batch 1350/2154 - Train Accuracy: 0.9609, Validation Accuracy: 0.9673, Loss: 0.0238
# Epoch   8 Batch 1400/2154 - Train Accuracy: 0.9737, Validation Accuracy: 0.9474, Loss: 0.0163
# Epoch   8 Batch 1450/2154 - Train Accuracy: 0.9737, Validation Accuracy: 0.9638, Loss: 0.0281
# Epoch   8 Batch 1500/2154 - Train Accuracy: 0.9844, Validation Accuracy: 0.9595, Loss: 0.0106
# Epoch   8 Batch 1550/2154 - Train Accuracy: 0.9773, Validation Accuracy: 0.9467, Loss: 0.0232
# Epoch   8 Batch 1600/2154 - Train Accuracy: 0.9500, Validation Accuracy: 0.9737, Loss: 0.0337
# Epoch   8 Batch 1650/2154 - Train Accuracy: 0.9814, Validation Accuracy: 0.9858, Loss: 0.0233
# Epoch   8 Batch 1700/2154 - Train Accuracy: 0.9672, Validation Accuracy: 0.9780, Loss: 0.0246
# Epoch   8 Batch 1750/2154 - Train Accuracy: 0.9383, Validation Accuracy: 0.9780, Loss: 0.0288
# Epoch   8 Batch 1800/2154 - Train Accuracy: 0.9508, Validation Accuracy: 0.9538, Loss: 0.0222
# Epoch   8 Batch 1850/2154 - Train Accuracy: 0.9696, Validation Accuracy: 0.9737, Loss: 0.0327
# Epoch   8 Batch 1900/2154 - Train Accuracy: 0.9906, Validation Accuracy: 0.9837, Loss: 0.0118
# Epoch   8 Batch 1950/2154 - Train Accuracy: 0.9953, Validation Accuracy: 0.9830, Loss: 0.0072
# Epoch   8 Batch 2000/2154 - Train Accuracy: 0.9570, Validation Accuracy: 0.9837, Loss: 0.0249
# Epoch   8 Batch 2050/2154 - Train Accuracy: 0.9400, Validation Accuracy: 0.9744, Loss: 0.0235
# Epoch   8 Batch 2100/2154 - Train Accuracy: 0.9836, Validation Accuracy: 0.9844, Loss: 0.0175
# Epoch   8 Batch 2150/2154 - Train Accuracy: 0.9911, Validation Accuracy: 0.9936, Loss: 0.0184
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    sentence = sentence.lower()
    sentence_ids = []
    words = sentence.split(" ")
    for word in words:
        if word in vocab_to_int.keys():
            sentence_ids.append(vocab_to_int[word])
        else:
            sentence_ids.append(vocab_to_int['<UNK>'])
    return sentence_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [53, 15, 16, 18, 199, 121, 172]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [128, 179, 288, 159, 273, 313, 334, 69, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
